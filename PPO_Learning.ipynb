# %% [markdown]
# # PPO

# %%
import numpy as np
import tensorflow as tf
import gymnasium as gym
import os
import matplotlib.pyplot as plt

# Disable eager execution to use TF1 style
tf.compat.v1.disable_eager_execution()
tf.compat.v1.reset_default_graph()

# %%
class ValueNetwork:
    def __init__(self, num_features, hidden_size, learning_rate=0.0001):
        self.num_features = num_features
        self.hidden_size = hidden_size
        self.graph = tf.Graph()
        with self.graph.as_default():
            self.sess = tf.compat.v1.Session()
            # Placeholders for state observations and target returns
            self.obs_ph = tf.compat.v1.placeholder(tf.float32, [None, num_features], name='obs')
            self.targets_ph = tf.compat.v1.placeholder(tf.float32, [None], name='targets')
            # Hidden layer using Keras Dense layer
            hidden = tf.compat.v1.keras.layers.Dense(hidden_size, activation=tf.nn.relu, name='hidden')(self.obs_ph)
            # Output layer: predicts a single scalar value per state
            self.value = tf.squeeze(tf.compat.v1.keras.layers.Dense(1, name='value_output')(hidden), axis=1)
            # Loss: Mean Squared Error (manually computed)
            self.loss = tf.reduce_mean(tf.square(self.targets_ph - self.value))
            # Optimizer and training op
            self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate)
            self.train_op = self.optimizer.minimize(self.loss)
            self.sess.run(tf.compat.v1.global_variables_initializer())
    
    def predict(self, states):
        return self.sess.run(self.value, feed_dict={self.obs_ph: states})
    
    def update(self, states, targets):
        loss_val, _ = self.sess.run([self.loss, self.train_op],
                                    feed_dict={self.obs_ph: states, self.targets_ph: targets})
        return loss_val

# %%
class PolicyNetwork:
    def __init__(self, num_features, num_actions, hidden_sizes, epsilon=0.2, learning_rate=0.0005):
        self.num_features = num_features
        self.num_actions = num_actions
        self.epsilon = epsilon  # PPO clipping parameter
        self.graph = tf.Graph()
        with self.graph.as_default():
            self.sess = tf.compat.v1.Session()
            # Placeholders for observations, actions taken, advantages, and old log probabilities
            self.obs_ph = tf.compat.v1.placeholder(tf.float32, [None, num_features], name='obs')
            self.actions_ph = tf.compat.v1.placeholder(tf.float32, [None, num_actions], name='actions')
            self.advantages_ph = tf.compat.v1.placeholder(tf.float32, [None], name='advantages')
            self.old_log_probs_ph = tf.compat.v1.placeholder(tf.float32, [None], name='old_log_probs')
            
            # Build hidden layers using Keras Dense layers
            out = self.obs_ph
            for i, size in enumerate(hidden_sizes):
                out = tf.compat.v1.keras.layers.Dense(size, activation=tf.nn.tanh, name=f'hidden_{i}')(out)
            # Output layer for the mean of the Gaussian distribution
            self.mean = tf.compat.v1.keras.layers.Dense(num_actions, activation=None, name='mean')(out)
            # Log standard deviation (trainable, state-independent)
            self.log_std = tf.compat.v1.get_variable("log_std", shape=[num_actions], initializer=tf.zeros_initializer())
            self.std = tf.exp(self.log_std)
            
            # Define a normal distribution for actions
            dist = tf.compat.v1.distributions.Normal(loc=self.mean, scale=self.std)
            # Sample actions from this distribution
            self.sampled_action = dist.sample()
            # Compute log probability of actions taken (summed over dimensions)
            self.log_prob = tf.reduce_sum(dist.log_prob(self.actions_ph), axis=1)
            
            # PPO loss: calculate the probability ratio and then clip it
            ratio = tf.exp(self.log_prob - self.old_log_probs_ph)
            surrogate1 = ratio * self.advantages_ph
            surrogate2 = tf.clip_by_value(ratio, 1 - self.epsilon, 1 + self.epsilon) * self.advantages_ph
            self.loss = -tf.reduce_mean(tf.minimum(surrogate1, surrogate2))
            
            
            # Optimizer and training operation
            self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate)
            self.train_op = self.optimizer.minimize(self.loss)
            self.sess.run(tf.compat.v1.global_variables_initializer())
    

    def predict(self, states):
        # Return the mean and log_std given states
        mean, log_std = self.sess.run([self.mean, self.log_std], feed_dict={self.obs_ph: states})
        std = np.exp(log_std)
        return mean, std


    def get_action(self, state):
        # For a single state, sample an action and compute its log probability
        feed_dict = {self.obs_ph: state[np.newaxis, :]}
        action = self.sess.run(self.sampled_action, feed_dict=feed_dict)
        log_prob = self.sess.run(self.log_prob, feed_dict={self.obs_ph: state[np.newaxis, :],
                                                            self.actions_ph: action,
                                                            self.old_log_probs_ph: [0.0]})
        return action[0], log_prob[0]
    

    def update(self, states, actions, advantages, old_log_probs):
        loss_val, _ = self.sess.run([self.loss, self.train_op],
                                     feed_dict={self.obs_ph: states,
                                                self.actions_ph: actions,
                                                self.advantages_ph: advantages,
                                                self.old_log_probs_ph: old_log_probs})
        return loss_val

# %%
class PPOAgent:
    def __init__(self, env, num_features, num_actions, gamma=0.99, lam=0.95,
                 policy_hidden_sizes=[256, 256], value_hidden_size=256,
                 policy_lr=0.0005, value_lr=0.001, epsilon=0.2):
        self.env = env
        self.gamma = gamma
        self.lam = lam
        self.num_features = num_features
        self.num_actions = num_actions
        
        self.policy_net = PolicyNetwork(num_features, num_actions, policy_hidden_sizes,
                                        epsilon=epsilon, learning_rate=policy_lr)
        self.value_net = ValueNetwork(num_features, value_hidden_size, learning_rate=value_lr)
    
    def discount_rewards(self, rewards):
        discounted = np.zeros_like(rewards)
        running = 0
        for t in reversed(range(len(rewards))):
            running = running * self.gamma + rewards[t]
            discounted[t] = running
        return discounted

    def compute_advantages(self, rewards, values):
        advantages = np.zeros_like(rewards)
        last_advantage = 0
        for t in reversed(range(len(rewards))):
            if t < len(rewards) - 1:
                delta = rewards[t] + self.gamma * values[t+1] - values[t]
            else:
                delta = rewards[t] - values[t]
            last_advantage = delta + self.gamma * self.lam * last_advantage
            advantages[t] = last_advantage
        # Normalize advantages
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        return advantages

    def train(self, num_episodes=5000, max_steps=1000):
        episode = 0
        while episode < num_episodes:
            states, actions, rewards, log_probs = [], [], [], []
            state, _ = self.env.reset()
            done = False
            ep_reward = 0
            for step in range(max_steps):
                action, log_prob = self.policy_net.get_action(state)
                next_state, reward, done, truncated, _ = self.env.step(action)
                states.append(state)
                actions.append(action)
                rewards.append(reward)
                log_probs.append(log_prob)
                ep_reward += reward
                state = next_state
                if done or truncated:
                    break

            states = np.array(states)
            actions = np.array(actions)
            rewards = np.array(rewards)
            log_probs = np.array(log_probs)
            
            # Get value predictions from the critic
            values = self.value_net.predict(states)
            discounted_rewards = self.discount_rewards(rewards)
            advantages = self.compute_advantages(rewards, values)
            
            v_loss = self.value_net.update(states, discounted_rewards)
            p_loss = self.policy_net.update(states, actions, advantages, log_probs)
            
            episode += 1
            print(f"Episode: {episode}, Total Reward: {ep_reward}, Value Loss: {v_loss:.4f}, Policy Loss: {p_loss:.4f}")

# %%
# Create the Ant environment from Gymnasium
env = gym.make("HalfCheetah-v5")  # Ant-v5 has 105 observations and 8 continuous actions
num_features = env.observation_space.shape[0]  # Should be 105 for Ant
num_actions = env.action_space.shape[0]          # Should be 8 for Ant

# Instantiate the PPO agent with appropriate hyperparameters
agent = PPOAgent(env, num_features=num_features, num_actions=num_actions,
                 gamma=0.99, lam=0.95,
                 policy_hidden_sizes=[256, 256],
                 value_hidden_size=256,
                 policy_lr=0.0005, value_lr=0.001,
                 epsilon=0.2)

# Train the agent (training Ant can be computationally heavy)
agent.train(num_episodes=7500, max_steps=1000)
# Out:
# WARNING:tensorflow:From /var/folders/6m/j_cns0zs42v4hh_y27kjf71h0000gn/T/ipykernel_8593/1775285382.py:26: Normal.__init__ (from tensorflow.python.ops.distributions.normal) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/distributions/normal.py:149: Distribution.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742025534.936271  384872 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# Episode: 1, Total Reward: -1141.1081082650492, Value Loss: 10786.2793, Policy Loss: -0.0000
# Episode: 2, Total Reward: -982.9717672459786, Value Loss: 8537.9854, Policy Loss: -0.0000
# Episode: 3, Total Reward: -991.1822057677507, Value Loss: 8575.7461, Policy Loss: 0.0000
# Episode: 4, Total Reward: -898.6022318736241, Value Loss: 6951.9473, Policy Loss: -0.0000
# Episode: 5, Total Reward: -1088.2012695739757, Value Loss: 10393.0615, Policy Loss: -0.0000
# Episode: 6, Total Reward: -902.3540625103278, Value Loss: 6853.1030, Policy Loss: -0.0000
# Episode: 7, Total Reward: -974.103979205937, Value Loss: 7735.9951, Policy Loss: 0.0000
# Episode: 8, Total Reward: -1018.4517743611752, Value Loss: 8223.1504, Policy Loss: 0.0000
# Episode: 9, Total Reward: -930.9428635397015, Value Loss: 6694.9648, Policy Loss: -0.0000
# Episode: 10, Total Reward: -1044.482929680336, Value Loss: 9335.7500, Policy Loss: -0.0000
# Episode: 11, Total Reward: -999.7458858083633, Value Loss: 7785.9790, Policy Loss: 0.0000
# Episode: 12, Total Reward: -874.6856923191497, Value Loss: 6470.0859, Policy Loss: -0.0000
# Episode: 13, Total Reward: -866.0901092986602, Value Loss: 5901.9800, Policy Loss: 0.0000
# Episode: 14, Total Reward: -804.8589797255926, Value Loss: 5138.0747, Policy Loss: 0.0000
# Episode: 15, Total Reward: -945.7542664140658, Value Loss: 6969.8911, Policy Loss: 0.0000
# Episode: 16, Total Reward: -927.7020760535563, Value Loss: 6557.2451, Policy Loss: -0.0000
# Episode: 17, Total Reward: -878.2921212445302, Value Loss: 6258.8218, Policy Loss: -0.0000
# Episode: 18, Total Reward: -857.0727113078622, Value Loss: 5400.1040, Policy Loss: 0.0000
# Episode: 19, Total Reward: -1030.8620983262992, Value Loss: 8007.0127, Policy Loss: -0.0000
# Episode: 20, Total Reward: -823.1582188389114, Value Loss: 5551.7427, Policy Loss: 0.0000
# Episode: 21, Total Reward: -883.8123688585163, Value Loss: 5352.5464, Policy Loss: 0.0000
# Episode: 22, Total Reward: -776.8631571349754, Value Loss: 4463.9878, Policy Loss: -0.0000
# Episode: 23, Total Reward: -851.3865878120472, Value Loss: 5330.7749, Policy Loss: 0.0000
# Episode: 24, Total Reward: -792.6907943678266, Value Loss: 4849.8857, Policy Loss: 0.0000
# Episode: 25, Total Reward: -836.9715947730155, Value Loss: 4797.9805, Policy Loss: 0.0000
# Episode: 26, Total Reward: -744.4136199861669, Value Loss: 3794.7925, Policy Loss: -0.0000
# Episode: 27, Total Reward: -686.6617974798792, Value Loss: 2703.5349, Policy Loss: 0.0000
# Episode: 28, Total Reward: -718.5123335692349, Value Loss: 3267.2451, Policy Loss: 0.0000
# Episode: 29, Total Reward: -682.789198338208, Value Loss: 2971.6790, Policy Loss: -0.0000
# Episode: 30, Total Reward: -730.995057326563, Value Loss: 3150.1870, Policy Loss: 0.0000
# Episode: 31, Total Reward: -685.293200378576, Value Loss: 2977.5813, Policy Loss: 0.0000
# Episode: 32, Total Reward: -699.3913834724307, Value Loss: 2871.5618, Policy Loss: 0.0000
# Episode: 33, Total Reward: -703.5612101555053, Value Loss: 2967.0317, Policy Loss: -0.0000
# Episode: 34, Total Reward: -911.7035455217881, Value Loss: 5770.6553, Policy Loss: 0.0000
# Episode: 35, Total Reward: -866.4063345222862, Value Loss: 5527.4717, Policy Loss: 0.0000
# Episode: 36, Total Reward: -768.9985605409222, Value Loss: 3699.0383, Policy Loss: 0.0000
# Episode: 37, Total Reward: -717.0581952862887, Value Loss: 2852.7073, Policy Loss: 0.0000
# Episode: 38, Total Reward: -670.7935511020743, Value Loss: 2646.6023, Policy Loss: 0.0000
# Episode: 39, Total Reward: -847.7668217549548, Value Loss: 4441.5835, Policy Loss: -0.0000
# Episode: 40, Total Reward: -628.891885359836, Value Loss: 2095.4087, Policy Loss: 0.0000
# Episode: 41, Total Reward: -860.564682889774, Value Loss: 4967.4438, Policy Loss: -0.0000
# Episode: 42, Total Reward: -724.3883319221762, Value Loss: 3399.9556, Policy Loss: -0.0000
# Episode: 43, Total Reward: -723.9901132205167, Value Loss: 3057.8994, Policy Loss: -0.0000
# Episode: 44, Total Reward: -763.2090198134197, Value Loss: 2982.5120, Policy Loss: -0.0000
# Episode: 45, Total Reward: -795.6569013653366, Value Loss: 3535.0942, Policy Loss: 0.0000
# Episode: 46, Total Reward: -741.5477835433445, Value Loss: 2818.8181, Policy Loss: -0.0000
# Episode: 47, Total Reward: -843.9654302436288, Value Loss: 4146.8726, Policy Loss: -0.0000
# Episode: 48, Total Reward: -965.4175864452045, Value Loss: 5288.0488, Policy Loss: 0.0000
# Episode: 49, Total Reward: -821.9819895296573, Value Loss: 4111.7373, Policy Loss: 0.0000
# Episode: 50, Total Reward: -735.1664223311216, Value Loss: 2737.6450, Policy Loss: 0.0000
# Episode: 51, Total Reward: -748.7232802986257, Value Loss: 3010.9199, Policy Loss: 0.0000
# Episode: 52, Total Reward: -756.218527037086, Value Loss: 2727.1870, Policy Loss: 0.0000
# Episode: 53, Total Reward: -744.8367414463215, Value Loss: 2863.1211, Policy Loss: -0.0000
# Episode: 54, Total Reward: -716.0911838043154, Value Loss: 2523.9370, Policy Loss: 0.0000
# Episode: 55, Total Reward: -872.7856732511888, Value Loss: 4685.3594, Policy Loss: -0.0000
# Episode: 56, Total Reward: -761.2153879297301, Value Loss: 3305.5920, Policy Loss: 0.0000
# Episode: 57, Total Reward: -818.5575726404863, Value Loss: 4035.2949, Policy Loss: 0.0000
# Episode: 58, Total Reward: -901.4063296150841, Value Loss: 4177.0391, Policy Loss: 0.0000
# Episode: 59, Total Reward: -862.4731733432558, Value Loss: 4322.8267, Policy Loss: 0.0000
# Episode: 60, Total Reward: -828.5315406055839, Value Loss: 4216.4551, Policy Loss: -0.0000
# Episode: 61, Total Reward: -726.0802944380275, Value Loss: 2279.7590, Policy Loss: 0.0000
# Episode: 62, Total Reward: -749.9673790875281, Value Loss: 2514.8550, Policy Loss: 0.0000
# Episode: 63, Total Reward: -807.1453765721639, Value Loss: 3015.0708, Policy Loss: -0.0000
# Episode: 64, Total Reward: -764.1331310354658, Value Loss: 2379.1560, Policy Loss: 0.0000
# Episode: 65, Total Reward: -735.8695608782563, Value Loss: 3086.7561, Policy Loss: 0.0000
# Episode: 66, Total Reward: -775.9488816017351, Value Loss: 2767.8389, Policy Loss: 0.0000
# Episode: 67, Total Reward: -855.0024159690067, Value Loss: 3232.1970, Policy Loss: 0.0000
# Episode: 68, Total Reward: -958.7640052889968, Value Loss: 4813.2471, Policy Loss: 0.0000
# Episode: 69, Total Reward: -816.6186682731335, Value Loss: 2590.8079, Policy Loss: -0.0000
# Episode: 70, Total Reward: -947.9068887632362, Value Loss: 4542.5527, Policy Loss: -0.0000
# Episode: 71, Total Reward: -873.964133867862, Value Loss: 3177.7942, Policy Loss: 0.0000
# Episode: 72, Total Reward: -864.8831263146977, Value Loss: 3615.3826, Policy Loss: 0.0000
# Episode: 73, Total Reward: -903.2191877018988, Value Loss: 4051.0007, Policy Loss: -0.0000
# Episode: 74, Total Reward: -770.0864843464915, Value Loss: 2180.0164, Policy Loss: 0.0000
# Episode: 75, Total Reward: -736.9246373004028, Value Loss: 2334.2451, Policy Loss: 0.0000
# Episode: 76, Total Reward: -709.8029601821715, Value Loss: 1829.7433, Policy Loss: -0.0000
# Episode: 77, Total Reward: -722.6605343568548, Value Loss: 1954.8149, Policy Loss: -0.0000
# Episode: 78, Total Reward: -848.447990278295, Value Loss: 2954.5393, Policy Loss: 0.0000
# Episode: 79, Total Reward: -869.189829229575, Value Loss: 2986.0200, Policy Loss: -0.0000
# Episode: 80, Total Reward: -809.4133711912343, Value Loss: 2015.9290, Policy Loss: -0.0000
# Episode: 81, Total Reward: -812.2415855945586, Value Loss: 2228.1655, Policy Loss: -0.0000
# Episode: 82, Total Reward: -783.3949593089591, Value Loss: 1950.2589, Policy Loss: -0.0000
# Episode: 83, Total Reward: -879.7182758591214, Value Loss: 3037.9121, Policy Loss: -0.0000
# Episode: 84, Total Reward: -767.4058634119689, Value Loss: 2050.0828, Policy Loss: 0.0000
# Episode: 85, Total Reward: -856.6580002574026, Value Loss: 2658.8855, Policy Loss: -0.0000
# Episode: 86, Total Reward: -791.1072841008197, Value Loss: 2168.1509, Policy Loss: 0.0000
# Episode: 87, Total Reward: -822.885738952304, Value Loss: 2204.8545, Policy Loss: -0.0000
# Episode: 88, Total Reward: -828.3809934263297, Value Loss: 2297.6519, Policy Loss: -0.0000
# Episode: 89, Total Reward: -821.3889814297858, Value Loss: 2322.6709, Policy Loss: 0.0000
# Episode: 90, Total Reward: -820.9273359239858, Value Loss: 2063.7988, Policy Loss: -0.0000
# Episode: 91, Total Reward: -855.6144135831503, Value Loss: 2334.0481, Policy Loss: -0.0000
# Episode: 92, Total Reward: -729.1077162837842, Value Loss: 1361.1737, Policy Loss: -0.0000
# Episode: 93, Total Reward: -740.2901104436189, Value Loss: 1490.0067, Policy Loss: -0.0000
# Episode: 94, Total Reward: -840.348077495918, Value Loss: 2034.7394, Policy Loss: -0.0000
# Episode: 95, Total Reward: -936.4784499368357, Value Loss: 2624.2510, Policy Loss: 0.0000
# Episode: 96, Total Reward: -794.7037853460496, Value Loss: 1853.7402, Policy Loss: -0.0000
# Episode: 97, Total Reward: -744.861336676398, Value Loss: 1847.5055, Policy Loss: 0.0000
# Episode: 98, Total Reward: -815.6496208974942, Value Loss: 1678.4391, Policy Loss: -0.0000
# Episode: 99, Total Reward: -879.9129056110975, Value Loss: 2406.5625, Policy Loss: -0.0000
# Episode: 100, Total Reward: -934.1010741988305, Value Loss: 2672.7520, Policy Loss: 0.0000
# Episode: 101, Total Reward: -952.4370459266743, Value Loss: 2646.7129, Policy Loss: 0.0000
# Episode: 102, Total Reward: -1065.0453911918887, Value Loss: 4028.1326, Policy Loss: -0.0000
# Episode: 103, Total Reward: -1045.6409422318673, Value Loss: 3726.6565, Policy Loss: -0.0000
# Episode: 104, Total Reward: -1016.6163496678938, Value Loss: 3298.1675, Policy Loss: 0.0000
# Episode: 105, Total Reward: -990.0386687431784, Value Loss: 3119.5398, Policy Loss: -0.0000
# Episode: 106, Total Reward: -932.8586584825496, Value Loss: 2610.2666, Policy Loss: -0.0000
# Episode: 107, Total Reward: -1070.2076207211246, Value Loss: 3174.2280, Policy Loss: -0.0000
# Episode: 108, Total Reward: -1038.6226241135155, Value Loss: 3011.1484, Policy Loss: -0.0000
# Episode: 109, Total Reward: -1075.6804680043388, Value Loss: 4261.0732, Policy Loss: 0.0000
# Episode: 110, Total Reward: -1089.4738623484448, Value Loss: 4015.9294, Policy Loss: 0.0000
# Episode: 111, Total Reward: -1020.9981594788032, Value Loss: 2498.8645, Policy Loss: -0.0000
# Episode: 112, Total Reward: -975.8323734585923, Value Loss: 2391.9075, Policy Loss: 0.0000
# Episode: 113, Total Reward: -982.6414915892688, Value Loss: 2342.9666, Policy Loss: 0.0000
# Episode: 114, Total Reward: -996.5327507948847, Value Loss: 2206.8767, Policy Loss: -0.0000
# Episode: 115, Total Reward: -912.8036622875127, Value Loss: 1696.1923, Policy Loss: -0.0000
# Episode: 116, Total Reward: -1030.2206234143475, Value Loss: 2296.9314, Policy Loss: 0.0000
# Episode: 117, Total Reward: -952.8593399848139, Value Loss: 1862.5076, Policy Loss: 0.0000
# Episode: 118, Total Reward: -992.3470409642583, Value Loss: 2110.6240, Policy Loss: -0.0000
# Episode: 119, Total Reward: -1003.017884386324, Value Loss: 1962.3981, Policy Loss: -0.0000
# Episode: 120, Total Reward: -944.7225071889791, Value Loss: 1652.7883, Policy Loss: 0.0000
# Episode: 121, Total Reward: -918.6840278493637, Value Loss: 1513.8339, Policy Loss: 0.0000
# Episode: 122, Total Reward: -1061.125583305586, Value Loss: 2795.2915, Policy Loss: -0.0000
# Episode: 123, Total Reward: -1024.9651320575067, Value Loss: 2409.3416, Policy Loss: 0.0000
# Episode: 124, Total Reward: -1114.9112831821255, Value Loss: 3829.0608, Policy Loss: 0.0000
# Episode: 125, Total Reward: -1020.7093675485303, Value Loss: 2027.5845, Policy Loss: -0.0000
# Episode: 126, Total Reward: -1042.9093583903566, Value Loss: 1868.1741, Policy Loss: 0.0000
# Episode: 127, Total Reward: -1019.8497087248902, Value Loss: 2101.8982, Policy Loss: -0.0000
# Episode: 128, Total Reward: -1125.9982804311942, Value Loss: 2442.7996, Policy Loss: 0.0000
# Episode: 129, Total Reward: -962.6623454820389, Value Loss: 1616.2463, Policy Loss: 0.0000
# Episode: 130, Total Reward: -965.0976005222728, Value Loss: 1426.3774, Policy Loss: -0.0000
# Episode: 131, Total Reward: -1162.7004475640783, Value Loss: 3016.9434, Policy Loss: -0.0000
# Episode: 132, Total Reward: -928.6003512231438, Value Loss: 1275.4263, Policy Loss: -0.0000
# Episode: 133, Total Reward: -907.0655184222704, Value Loss: 1148.0848, Policy Loss: 0.0000
# Episode: 134, Total Reward: -1063.6757352972272, Value Loss: 2568.0085, Policy Loss: -0.0000
# Episode: 135, Total Reward: -980.5811670066694, Value Loss: 1257.8959, Policy Loss: -0.0000
# Episode: 136, Total Reward: -901.8766355041051, Value Loss: 1547.5135, Policy Loss: 0.0000
# Episode: 137, Total Reward: -888.331561636238, Value Loss: 978.9130, Policy Loss: -0.0000
# Episode: 138, Total Reward: -958.3366032317928, Value Loss: 1570.1453, Policy Loss: 0.0000
# Episode: 139, Total Reward: -920.8408638797898, Value Loss: 862.0071, Policy Loss: 0.0000
# Episode: 140, Total Reward: -964.8011624330411, Value Loss: 1277.0664, Policy Loss: -0.0000
# Episode: 141, Total Reward: -888.1730982173899, Value Loss: 1098.1600, Policy Loss: -0.0000
# Episode: 142, Total Reward: -854.134742656992, Value Loss: 985.9191, Policy Loss: -0.0000
# Episode: 143, Total Reward: -901.4975920198631, Value Loss: 880.8176, Policy Loss: 0.0000
# Episode: 144, Total Reward: -845.5089380781709, Value Loss: 1225.9344, Policy Loss: -0.0000
# Episode: 145, Total Reward: -895.6775446233355, Value Loss: 805.0790, Policy Loss: 0.0000
# Episode: 146, Total Reward: -942.3412272544927, Value Loss: 1309.7937, Policy Loss: 0.0000
# Episode: 147, Total Reward: -940.0455490401802, Value Loss: 1042.1836, Policy Loss: 0.0000
# Episode: 148, Total Reward: -841.8316518975096, Value Loss: 855.8749, Policy Loss: 0.0000
# Episode: 149, Total Reward: -935.5864147359891, Value Loss: 1256.9702, Policy Loss: -0.0000
# Episode: 150, Total Reward: -762.9968727790466, Value Loss: 899.0698, Policy Loss: -0.0000
# Episode: 151, Total Reward: -913.2240049316481, Value Loss: 1133.9263, Policy Loss: -0.0000
# Episode: 152, Total Reward: -934.511586036282, Value Loss: 1904.9081, Policy Loss: 0.0000
# Episode: 153, Total Reward: -861.2897720093345, Value Loss: 1153.3392, Policy Loss: 0.0000
# Episode: 154, Total Reward: -899.9287970084152, Value Loss: 971.5203, Policy Loss: 0.0000
# Episode: 155, Total Reward: -979.9053927054795, Value Loss: 1229.9937, Policy Loss: 0.0000
# Episode: 156, Total Reward: -929.7307060688771, Value Loss: 1389.7483, Policy Loss: -0.0000
# Episode: 157, Total Reward: -921.1445742358577, Value Loss: 780.4610, Policy Loss: -0.0000
# Episode: 158, Total Reward: -911.6349031970606, Value Loss: 866.6621, Policy Loss: 0.0000
# Episode: 159, Total Reward: -852.8901475313397, Value Loss: 943.8597, Policy Loss: -0.0000
# Episode: 160, Total Reward: -826.4402699244638, Value Loss: 683.1761, Policy Loss: 0.0000
# Episode: 161, Total Reward: -973.7073886284275, Value Loss: 1195.5051, Policy Loss: -0.0000
# Episode: 162, Total Reward: -824.9116990496551, Value Loss: 766.1240, Policy Loss: -0.0000
# Episode: 163, Total Reward: -871.5613859173054, Value Loss: 771.3749, Policy Loss: 0.0000
# Episode: 164, Total Reward: -981.8747616502906, Value Loss: 1094.1925, Policy Loss: -0.0000
# Episode: 165, Total Reward: -867.3409452170067, Value Loss: 809.3500, Policy Loss: -0.0000
# Episode: 166, Total Reward: -878.3385626464099, Value Loss: 899.4865, Policy Loss: -0.0000
# Episode: 167, Total Reward: -770.7511810994965, Value Loss: 732.5009, Policy Loss: -0.0000
# Episode: 168, Total Reward: -948.1577224841479, Value Loss: 1870.7919, Policy Loss: 0.0000
# Episode: 169, Total Reward: -976.4299375354196, Value Loss: 2246.1931, Policy Loss: -0.0000
# Episode: 170, Total Reward: -840.5156750620781, Value Loss: 1054.9524, Policy Loss: 0.0000
# Episode: 171, Total Reward: -843.1205249020438, Value Loss: 667.4208, Policy Loss: 0.0000
# Episode: 172, Total Reward: -920.4301447280038, Value Loss: 1228.5957, Policy Loss: -0.0000
# Episode: 173, Total Reward: -928.2162972559936, Value Loss: 1137.7163, Policy Loss: -0.0000
# Episode: 174, Total Reward: -805.3396062427285, Value Loss: 604.1013, Policy Loss: 0.0000
# Episode: 175, Total Reward: -854.385403972356, Value Loss: 764.7433, Policy Loss: -0.0000
# Episode: 176, Total Reward: -917.5976464377276, Value Loss: 1286.2556, Policy Loss: -0.0000
# Episode: 177, Total Reward: -1083.565660041921, Value Loss: 1929.1631, Policy Loss: 0.0000
# Episode: 178, Total Reward: -920.1330462202505, Value Loss: 1249.6470, Policy Loss: -0.0000
# Episode: 179, Total Reward: -964.5003470946883, Value Loss: 1274.6655, Policy Loss: 0.0000
# Episode: 180, Total Reward: -1114.8547758937657, Value Loss: 2200.6951, Policy Loss: -0.0000
# Episode: 181, Total Reward: -864.7380484433921, Value Loss: 1202.9757, Policy Loss: 0.0000
# Episode: 182, Total Reward: -1016.2851883204393, Value Loss: 1043.3954, Policy Loss: -0.0000
# Episode: 183, Total Reward: -1021.8956068842766, Value Loss: 1152.5585, Policy Loss: -0.0000
# Episode: 184, Total Reward: -973.688877393964, Value Loss: 1493.1475, Policy Loss: 0.0000
# Episode: 185, Total Reward: -1296.08183900166, Value Loss: 3550.3071, Policy Loss: 0.0000
# Episode: 186, Total Reward: -1137.8486592981149, Value Loss: 1642.0441, Policy Loss: 0.0000
# Episode: 187, Total Reward: -998.6481406099261, Value Loss: 1197.3727, Policy Loss: 0.0000
# Episode: 188, Total Reward: -850.3308256392302, Value Loss: 1399.1520, Policy Loss: -0.0000
# Episode: 189, Total Reward: -1232.310683125514, Value Loss: 2265.8557, Policy Loss: -0.0000
# Episode: 190, Total Reward: -1107.8404319749827, Value Loss: 1344.8466, Policy Loss: -0.0000
# Episode: 191, Total Reward: -1049.121334416124, Value Loss: 1850.5074, Policy Loss: 0.0000
# Episode: 192, Total Reward: -935.3943723785304, Value Loss: 1336.9442, Policy Loss: 0.0000
# Episode: 193, Total Reward: -1105.4723566654293, Value Loss: 2067.6846, Policy Loss: -0.0000
# Episode: 194, Total Reward: -907.1107523781676, Value Loss: 880.4896, Policy Loss: 0.0000
# Episode: 195, Total Reward: -924.5524022451749, Value Loss: 988.3965, Policy Loss: 0.0000
# Episode: 196, Total Reward: -849.4855231355401, Value Loss: 1240.3231, Policy Loss: -0.0000
# Episode: 197, Total Reward: -974.9664624527115, Value Loss: 1738.7834, Policy Loss: -0.0000
# Episode: 198, Total Reward: -1041.6574883072653, Value Loss: 1374.3885, Policy Loss: 0.0000
# Episode: 199, Total Reward: -945.3839401663276, Value Loss: 962.4655, Policy Loss: 0.0000
# Episode: 200, Total Reward: -1207.470443175853, Value Loss: 2062.7019, Policy Loss: -0.0000
# Episode: 201, Total Reward: -1353.4349467640595, Value Loss: 2525.7559, Policy Loss: 0.0000
# Episode: 202, Total Reward: -1189.702843337579, Value Loss: 2412.2373, Policy Loss: 0.0000
# Episode: 203, Total Reward: -1011.9838892906054, Value Loss: 1323.0588, Policy Loss: 0.0000
# Episode: 204, Total Reward: -970.5659793187738, Value Loss: 1121.0837, Policy Loss: 0.0000
# Episode: 205, Total Reward: -1460.7879644486393, Value Loss: 3306.1604, Policy Loss: -0.0000
# Episode: 206, Total Reward: -1220.047887626089, Value Loss: 3104.0247, Policy Loss: 0.0000
# Episode: 207, Total Reward: -1371.7862839039906, Value Loss: 4893.8789, Policy Loss: -0.0000
# Episode: 208, Total Reward: -1385.1431611439111, Value Loss: 3449.2385, Policy Loss: 0.0000
# Episode: 209, Total Reward: -1343.4552865619878, Value Loss: 3490.0723, Policy Loss: 0.0000
# Episode: 210, Total Reward: -1301.324971492118, Value Loss: 2860.8694, Policy Loss: -0.0000
# Episode: 211, Total Reward: -1241.7528058585751, Value Loss: 2446.6289, Policy Loss: 0.0000
# Episode: 212, Total Reward: -1334.4800466516817, Value Loss: 3624.3042, Policy Loss: 0.0000
# Episode: 213, Total Reward: -1245.8292940264664, Value Loss: 1533.9413, Policy Loss: -0.0000
# Episode: 214, Total Reward: -1404.7256326404495, Value Loss: 4087.1475, Policy Loss: 0.0000
# Episode: 215, Total Reward: -1171.2202382619087, Value Loss: 1490.9614, Policy Loss: 0.0000
# Episode: 216, Total Reward: -1217.7226812730125, Value Loss: 1745.0778, Policy Loss: -0.0000
# Episode: 217, Total Reward: -1113.2511764981555, Value Loss: 1787.3240, Policy Loss: 0.0000
# Episode: 218, Total Reward: -1275.677897421128, Value Loss: 2561.8816, Policy Loss: 0.0000
# Episode: 219, Total Reward: -1174.6686986452291, Value Loss: 1951.6653, Policy Loss: 0.0000
# Episode: 220, Total Reward: -1176.1058784314237, Value Loss: 1242.3745, Policy Loss: -0.0000
# Episode: 221, Total Reward: -1206.3129490205915, Value Loss: 1523.6212, Policy Loss: -0.0000
# Episode: 222, Total Reward: -1189.5711102208245, Value Loss: 2113.7332, Policy Loss: 0.0000
# Episode: 223, Total Reward: -1234.106029096998, Value Loss: 2242.8765, Policy Loss: 0.0000
# Episode: 224, Total Reward: -1134.4246753420334, Value Loss: 1423.1426, Policy Loss: 0.0000
# Episode: 225, Total Reward: -1187.1754830123625, Value Loss: 1286.6837, Policy Loss: 0.0000
# Episode: 226, Total Reward: -1247.7748653700712, Value Loss: 2276.6218, Policy Loss: -0.0000
# Episode: 227, Total Reward: -1166.5113685934768, Value Loss: 1633.8462, Policy Loss: 0.0000
# Episode: 228, Total Reward: -1101.0101878490107, Value Loss: 1032.2667, Policy Loss: -0.0000
# Episode: 229, Total Reward: -1126.939466982901, Value Loss: 1274.4423, Policy Loss: 0.0000
# Episode: 230, Total Reward: -1023.834618847058, Value Loss: 968.2913, Policy Loss: -0.0000
# Episode: 231, Total Reward: -915.8363599161147, Value Loss: 1426.7166, Policy Loss: -0.0000
# Episode: 232, Total Reward: -936.6160689738963, Value Loss: 1098.1061, Policy Loss: 0.0000
# Episode: 233, Total Reward: -1072.9788744399714, Value Loss: 1465.0166, Policy Loss: -0.0000
# Episode: 234, Total Reward: -950.0431025753196, Value Loss: 1346.6665, Policy Loss: 0.0000
# Episode: 235, Total Reward: -956.9979125700808, Value Loss: 1232.4219, Policy Loss: 0.0000
# Episode: 236, Total Reward: -922.7849024726904, Value Loss: 866.0323, Policy Loss: -0.0000
# Episode: 237, Total Reward: -1043.7612914370138, Value Loss: 1155.3103, Policy Loss: 0.0000
# Episode: 238, Total Reward: -906.6554377718044, Value Loss: 1503.1748, Policy Loss: 0.0000
# Episode: 239, Total Reward: -836.5837600629973, Value Loss: 1318.5453, Policy Loss: -0.0000
# Episode: 240, Total Reward: -883.6261985578276, Value Loss: 1266.8967, Policy Loss: 0.0000
# Episode: 241, Total Reward: -848.701920352951, Value Loss: 1557.7762, Policy Loss: 0.0000
# Episode: 242, Total Reward: -831.530034910014, Value Loss: 1380.9988, Policy Loss: 0.0000
# Episode: 243, Total Reward: -838.1382910267904, Value Loss: 944.7074, Policy Loss: -0.0000
# Episode: 244, Total Reward: -860.2556312984603, Value Loss: 1243.4880, Policy Loss: 0.0000
# Episode: 245, Total Reward: -907.515729230258, Value Loss: 1880.7720, Policy Loss: -0.0000
# Episode: 246, Total Reward: -770.4902853697287, Value Loss: 1329.6611, Policy Loss: -0.0000
# Episode: 247, Total Reward: -732.6688911894659, Value Loss: 1554.6112, Policy Loss: 0.0000
# Episode: 248, Total Reward: -757.7725507572683, Value Loss: 1039.3031, Policy Loss: 0.0000
# Episode: 249, Total Reward: -832.7152300866524, Value Loss: 1330.5500, Policy Loss: 0.0000
# Episode: 250, Total Reward: -851.6107195312399, Value Loss: 1203.6711, Policy Loss: -0.0000
# Episode: 251, Total Reward: -777.5004985280458, Value Loss: 1112.4440, Policy Loss: -0.0000
# Episode: 252, Total Reward: -766.0826533632882, Value Loss: 1304.6617, Policy Loss: 0.0000
# Episode: 253, Total Reward: -842.3498635980783, Value Loss: 1358.9607, Policy Loss: 0.0000
# Episode: 254, Total Reward: -820.593220306598, Value Loss: 995.4551, Policy Loss: 0.0000
# Episode: 255, Total Reward: -892.8939963970025, Value Loss: 906.5805, Policy Loss: -0.0000
# Episode: 256, Total Reward: -746.334522291312, Value Loss: 977.6614, Policy Loss: -0.0000
# Episode: 257, Total Reward: -639.5727124222024, Value Loss: 1562.3622, Policy Loss: 0.0000
# Episode: 258, Total Reward: -737.116126281793, Value Loss: 1008.1976, Policy Loss: -0.0000
# Episode: 259, Total Reward: -750.1529694202302, Value Loss: 1008.9214, Policy Loss: 0.0000
# Episode: 260, Total Reward: -817.3710757032461, Value Loss: 1140.9742, Policy Loss: -0.0000
# Episode: 261, Total Reward: -792.462282819403, Value Loss: 1059.4061, Policy Loss: -0.0000
# Episode: 262, Total Reward: -831.5911401933961, Value Loss: 1040.0092, Policy Loss: -0.0000
# Episode: 263, Total Reward: -678.0960357233824, Value Loss: 1031.0685, Policy Loss: 0.0000
# Episode: 264, Total Reward: -904.8579559133829, Value Loss: 834.1155, Policy Loss: 0.0000
# Episode: 265, Total Reward: -969.7608136583863, Value Loss: 1049.3043, Policy Loss: -0.0000
# Episode: 266, Total Reward: -810.6725489073143, Value Loss: 852.5870, Policy Loss: 0.0000
# Episode: 267, Total Reward: -781.1914584268922, Value Loss: 803.5579, Policy Loss: 0.0000
# Episode: 268, Total Reward: -899.5559979227083, Value Loss: 883.0522, Policy Loss: 0.0000
# Episode: 269, Total Reward: -904.2827233436254, Value Loss: 729.0148, Policy Loss: -0.0000
# Episode: 270, Total Reward: -1025.1874067797883, Value Loss: 1288.7612, Policy Loss: 0.0000
# Episode: 271, Total Reward: -915.3869089954618, Value Loss: 816.1973, Policy Loss: -0.0000
# Episode: 272, Total Reward: -791.5949352297067, Value Loss: 1366.2672, Policy Loss: 0.0000
# Episode: 273, Total Reward: -1065.1453564757055, Value Loss: 1183.7563, Policy Loss: -0.0000
# Episode: 274, Total Reward: -905.6827553351043, Value Loss: 759.9925, Policy Loss: -0.0000
# Episode: 275, Total Reward: -1049.4772898406632, Value Loss: 1899.2543, Policy Loss: 0.0000
# Episode: 276, Total Reward: -811.4902017460577, Value Loss: 907.3364, Policy Loss: -0.0000
# Episode: 277, Total Reward: -930.9889827793395, Value Loss: 634.7584, Policy Loss: -0.0000
# Episode: 278, Total Reward: -1062.5578572545348, Value Loss: 2129.6135, Policy Loss: 0.0000
# Episode: 279, Total Reward: -829.0617716183211, Value Loss: 701.3652, Policy Loss: -0.0000
# Episode: 280, Total Reward: -694.4921383914542, Value Loss: 759.9532, Policy Loss: 0.0000
# Episode: 281, Total Reward: -949.2417402628275, Value Loss: 1183.5143, Policy Loss: -0.0000
# Episode: 282, Total Reward: -872.7944211296494, Value Loss: 694.9295, Policy Loss: 0.0000
# Episode: 283, Total Reward: -944.5477218404325, Value Loss: 831.1557, Policy Loss: -0.0000
# Episode: 284, Total Reward: -1070.3299225200938, Value Loss: 1692.7744, Policy Loss: -0.0000
# Episode: 285, Total Reward: -998.0718157397582, Value Loss: 991.6446, Policy Loss: 0.0000
# Episode: 286, Total Reward: -945.5942994323652, Value Loss: 962.6904, Policy Loss: 0.0000
# Episode: 287, Total Reward: -1078.7056353804921, Value Loss: 2252.7117, Policy Loss: -0.0000
# Episode: 288, Total Reward: -744.1178190665851, Value Loss: 880.8907, Policy Loss: 0.0000
# Episode: 289, Total Reward: -884.1929692023434, Value Loss: 1005.8192, Policy Loss: -0.0000
# Episode: 290, Total Reward: -953.2913256066895, Value Loss: 1212.5090, Policy Loss: -0.0000
# Episode: 291, Total Reward: -883.2142328845813, Value Loss: 1040.4769, Policy Loss: -0.0000
# Episode: 292, Total Reward: -935.8385366866859, Value Loss: 977.0869, Policy Loss: -0.0000
# Episode: 293, Total Reward: -822.5679688250185, Value Loss: 796.4738, Policy Loss: -0.0000
# Episode: 294, Total Reward: -917.6658392986135, Value Loss: 847.6091, Policy Loss: 0.0000
# Episode: 295, Total Reward: -837.7139316462542, Value Loss: 884.1163, Policy Loss: 0.0000
# Episode: 296, Total Reward: -860.2333938820952, Value Loss: 690.6451, Policy Loss: -0.0000
# Episode: 297, Total Reward: -894.5005635836759, Value Loss: 647.6270, Policy Loss: 0.0000
# Episode: 298, Total Reward: -767.6135985781328, Value Loss: 990.2053, Policy Loss: 0.0000
# Episode: 299, Total Reward: -866.9772330942939, Value Loss: 1169.2054, Policy Loss: -0.0000
# Episode: 300, Total Reward: -766.4932060946027, Value Loss: 752.4371, Policy Loss: -0.0000
# Episode: 301, Total Reward: -692.713906568211, Value Loss: 828.0292, Policy Loss: -0.0000
# Episode: 302, Total Reward: -909.9012689852833, Value Loss: 772.9567, Policy Loss: 0.0000
# Episode: 303, Total Reward: -792.1411598815973, Value Loss: 921.3198, Policy Loss: 0.0000
# Episode: 304, Total Reward: -898.7255608728414, Value Loss: 1077.6742, Policy Loss: -0.0000
# Episode: 305, Total Reward: -823.4885915328526, Value Loss: 616.3872, Policy Loss: -0.0000
# Episode: 306, Total Reward: -880.6438110765997, Value Loss: 819.5028, Policy Loss: -0.0000
# Episode: 307, Total Reward: -948.0140268769275, Value Loss: 1003.6996, Policy Loss: 0.0000
# Episode: 308, Total Reward: -843.2770652336679, Value Loss: 759.6696, Policy Loss: -0.0000
# Episode: 309, Total Reward: -799.3354738437373, Value Loss: 668.8039, Policy Loss: 0.0000
# Episode: 310, Total Reward: -762.8497305361725, Value Loss: 729.4819, Policy Loss: 0.0000
# Episode: 311, Total Reward: -784.6429440246164, Value Loss: 829.1705, Policy Loss: -0.0000
# Episode: 312, Total Reward: -731.0139118416502, Value Loss: 632.1411, Policy Loss: -0.0000
# Episode: 313, Total Reward: -769.3201675075105, Value Loss: 905.9788, Policy Loss: 0.0000
# Episode: 314, Total Reward: -775.5109995497896, Value Loss: 648.4073, Policy Loss: -0.0000
# Episode: 315, Total Reward: -709.4513989956287, Value Loss: 1015.4783, Policy Loss: -0.0000
# Episode: 316, Total Reward: -803.0733685603719, Value Loss: 662.6027, Policy Loss: 0.0000
# Episode: 317, Total Reward: -798.0411662534844, Value Loss: 711.8329, Policy Loss: -0.0000
# Episode: 318, Total Reward: -578.7329981121738, Value Loss: 1066.7800, Policy Loss: 0.0000
# Episode: 319, Total Reward: -793.819955522563, Value Loss: 793.9816, Policy Loss: 0.0000
# Episode: 320, Total Reward: -754.5630785761335, Value Loss: 800.8159, Policy Loss: 0.0000
# Episode: 321, Total Reward: -773.2720097484194, Value Loss: 881.9725, Policy Loss: 0.0000
# Episode: 322, Total Reward: -717.487140444539, Value Loss: 783.5905, Policy Loss: 0.0000
# Episode: 323, Total Reward: -726.1555415234477, Value Loss: 631.6460, Policy Loss: 0.0000
# Episode: 324, Total Reward: -762.018288613676, Value Loss: 687.5754, Policy Loss: 0.0000
# Episode: 325, Total Reward: -764.9470911526173, Value Loss: 604.9481, Policy Loss: -0.0000
# Episode: 326, Total Reward: -779.2198009805015, Value Loss: 741.1440, Policy Loss: 0.0000
# Episode: 327, Total Reward: -800.7207730556602, Value Loss: 1014.8945, Policy Loss: -0.0000
# Episode: 328, Total Reward: -827.4069573014914, Value Loss: 649.0530, Policy Loss: -0.0000
# Episode: 329, Total Reward: -853.4361603337891, Value Loss: 851.6464, Policy Loss: 0.0000
# Episode: 330, Total Reward: -770.6748394579774, Value Loss: 505.1307, Policy Loss: 0.0000
# Episode: 331, Total Reward: -645.9237090628444, Value Loss: 634.5006, Policy Loss: -0.0000
# Episode: 332, Total Reward: -708.7526894983462, Value Loss: 819.2381, Policy Loss: 0.0000
# Episode: 333, Total Reward: -815.7032632292965, Value Loss: 746.1172, Policy Loss: -0.0000
# Episode: 334, Total Reward: -766.0551317302125, Value Loss: 1107.9532, Policy Loss: -0.0000
# Episode: 335, Total Reward: -889.8711371393601, Value Loss: 1344.3354, Policy Loss: -0.0000
# Episode: 336, Total Reward: -890.1197783405524, Value Loss: 865.9614, Policy Loss: -0.0000
# Episode: 337, Total Reward: -638.5537453372165, Value Loss: 629.1111, Policy Loss: 0.0000
# Episode: 338, Total Reward: -725.7074524715564, Value Loss: 580.7269, Policy Loss: -0.0000
# Episode: 339, Total Reward: -816.2830317123348, Value Loss: 709.9682, Policy Loss: -0.0000
# Episode: 340, Total Reward: -664.788483418011, Value Loss: 738.2939, Policy Loss: -0.0000
# Episode: 341, Total Reward: -696.0204280390566, Value Loss: 630.1206, Policy Loss: 0.0000
# Episode: 342, Total Reward: -770.739770484999, Value Loss: 669.5737, Policy Loss: 0.0000
# Episode: 343, Total Reward: -655.599991773462, Value Loss: 840.9567, Policy Loss: -0.0000
# Episode: 344, Total Reward: -662.5392789790781, Value Loss: 635.2887, Policy Loss: 0.0000
# Episode: 345, Total Reward: -870.3594455291982, Value Loss: 783.9850, Policy Loss: -0.0000
# Episode: 346, Total Reward: -772.587393867965, Value Loss: 753.5693, Policy Loss: 0.0000
# Episode: 347, Total Reward: -977.1136923862077, Value Loss: 1105.1101, Policy Loss: 0.0000
# Episode: 348, Total Reward: -844.9691410621193, Value Loss: 626.9937, Policy Loss: 0.0000
# Episode: 349, Total Reward: -794.5896059142299, Value Loss: 805.9050, Policy Loss: -0.0000
# Episode: 350, Total Reward: -828.3324591939811, Value Loss: 1037.5922, Policy Loss: 0.0000
# Episode: 351, Total Reward: -776.0898920265344, Value Loss: 615.1771, Policy Loss: 0.0000
# Episode: 352, Total Reward: -794.6098263650621, Value Loss: 710.3935, Policy Loss: -0.0000
# Episode: 353, Total Reward: -832.9999973798158, Value Loss: 820.8947, Policy Loss: 0.0000
# Episode: 354, Total Reward: -754.0324953899038, Value Loss: 729.7810, Policy Loss: -0.0000
# Episode: 355, Total Reward: -760.238259831187, Value Loss: 769.9769, Policy Loss: -0.0000
# Episode: 356, Total Reward: -886.3569036463473, Value Loss: 818.5511, Policy Loss: -0.0000
# Episode: 357, Total Reward: -767.1808769776416, Value Loss: 705.5926, Policy Loss: 0.0000
# Episode: 358, Total Reward: -777.3639603308961, Value Loss: 713.8907, Policy Loss: -0.0000
# Episode: 359, Total Reward: -854.0078335903153, Value Loss: 759.7316, Policy Loss: 0.0000
# Episode: 360, Total Reward: -691.8089769667491, Value Loss: 1093.3175, Policy Loss: -0.0000
# Episode: 361, Total Reward: -836.8327908869037, Value Loss: 1214.9952, Policy Loss: -0.0000
# Episode: 362, Total Reward: -898.1878997226381, Value Loss: 713.8138, Policy Loss: -0.0000
# Episode: 363, Total Reward: -795.7275423046891, Value Loss: 678.5300, Policy Loss: 0.0000
# Episode: 364, Total Reward: -975.6560561681695, Value Loss: 1082.2908, Policy Loss: -0.0000
# Episode: 365, Total Reward: -931.2313473957055, Value Loss: 747.7114, Policy Loss: 0.0000
# Episode: 366, Total Reward: -700.8140781348144, Value Loss: 737.6040, Policy Loss: -0.0000
# Episode: 367, Total Reward: -789.8305284377451, Value Loss: 879.4543, Policy Loss: -0.0000
# Episode: 368, Total Reward: -918.7487696390231, Value Loss: 699.8958, Policy Loss: 0.0000
# Episode: 369, Total Reward: -983.8448721284329, Value Loss: 1024.0420, Policy Loss: -0.0000
# Episode: 370, Total Reward: -983.9336520877666, Value Loss: 1287.8496, Policy Loss: 0.0000
# Episode: 371, Total Reward: -955.9731461225973, Value Loss: 970.6552, Policy Loss: -0.0000
# Episode: 372, Total Reward: -924.2408262988005, Value Loss: 1359.3914, Policy Loss: -0.0000
# Episode: 373, Total Reward: -741.9663318749426, Value Loss: 697.3622, Policy Loss: -0.0000
# Episode: 374, Total Reward: -928.9037425964558, Value Loss: 808.8038, Policy Loss: 0.0000
# Episode: 375, Total Reward: -966.9607796273829, Value Loss: 1177.9419, Policy Loss: 0.0000
# Episode: 376, Total Reward: -921.5892372815147, Value Loss: 1308.8389, Policy Loss: -0.0000
# Episode: 377, Total Reward: -997.3688863851603, Value Loss: 984.1973, Policy Loss: -0.0000
# Episode: 378, Total Reward: -978.8167782469427, Value Loss: 1353.6071, Policy Loss: -0.0000
# Episode: 379, Total Reward: -895.373566869122, Value Loss: 879.2379, Policy Loss: -0.0000
# Episode: 380, Total Reward: -914.159405344552, Value Loss: 1079.6055, Policy Loss: 0.0000
# Episode: 381, Total Reward: -1041.2516543130193, Value Loss: 1082.6628, Policy Loss: -0.0000
# Episode: 382, Total Reward: -911.7977895809088, Value Loss: 717.9937, Policy Loss: -0.0000
# Episode: 383, Total Reward: -962.3786625026332, Value Loss: 1061.6975, Policy Loss: -0.0000
# Episode: 384, Total Reward: -942.2247954350471, Value Loss: 869.2734, Policy Loss: 0.0000
# Episode: 385, Total Reward: -998.3207633469393, Value Loss: 1028.0603, Policy Loss: -0.0000
# Episode: 386, Total Reward: -1002.5914179330275, Value Loss: 959.7152, Policy Loss: 0.0000
# Episode: 387, Total Reward: -909.1144810864523, Value Loss: 809.2709, Policy Loss: -0.0000
# Episode: 388, Total Reward: -936.690426011987, Value Loss: 770.4866, Policy Loss: -0.0000
# Episode: 389, Total Reward: -1020.9398040281174, Value Loss: 1522.8461, Policy Loss: -0.0000
# Episode: 390, Total Reward: -869.3106484286822, Value Loss: 1004.1503, Policy Loss: -0.0000
# Episode: 391, Total Reward: -1003.8226565886129, Value Loss: 915.3373, Policy Loss: 0.0000
# Episode: 392, Total Reward: -977.367529508523, Value Loss: 1336.3610, Policy Loss: 0.0000
# Episode: 393, Total Reward: -1020.7117901583566, Value Loss: 899.9008, Policy Loss: -0.0000
# Episode: 394, Total Reward: -1024.9803721172336, Value Loss: 883.8450, Policy Loss: -0.0000
# Episode: 395, Total Reward: -1050.849883571174, Value Loss: 902.2469, Policy Loss: 0.0000
# Episode: 396, Total Reward: -854.7585197634406, Value Loss: 766.7705, Policy Loss: -0.0000
# Episode: 397, Total Reward: -874.0191503756083, Value Loss: 1136.6345, Policy Loss: -0.0000
# Episode: 398, Total Reward: -927.842540498498, Value Loss: 803.3447, Policy Loss: 0.0000
# Episode: 399, Total Reward: -1079.1456568964045, Value Loss: 960.4816, Policy Loss: -0.0000
# Episode: 400, Total Reward: -1022.0790921675675, Value Loss: 1105.8405, Policy Loss: 0.0000
# Episode: 401, Total Reward: -842.0860443419389, Value Loss: 734.4007, Policy Loss: 0.0000
# Episode: 402, Total Reward: -1006.8052189276468, Value Loss: 926.4908, Policy Loss: 0.0000
# Episode: 403, Total Reward: -846.9936755392893, Value Loss: 1155.6639, Policy Loss: -0.0000
# Episode: 404, Total Reward: -1057.4829147264488, Value Loss: 1117.7317, Policy Loss: -0.0000
# Episode: 405, Total Reward: -995.2758981010322, Value Loss: 921.3902, Policy Loss: -0.0000
# Episode: 406, Total Reward: -945.9999131645959, Value Loss: 755.2198, Policy Loss: -0.0000
# Episode: 407, Total Reward: -881.756858161117, Value Loss: 714.1948, Policy Loss: -0.0000
# Episode: 408, Total Reward: -829.8889079666682, Value Loss: 926.5824, Policy Loss: -0.0000
# Episode: 409, Total Reward: -1004.1041692990439, Value Loss: 707.8084, Policy Loss: -0.0000
# Episode: 410, Total Reward: -855.200597950056, Value Loss: 636.1604, Policy Loss: 0.0000
# Episode: 411, Total Reward: -956.532128225926, Value Loss: 803.1900, Policy Loss: -0.0000
# Episode: 412, Total Reward: -897.3495666124253, Value Loss: 783.7974, Policy Loss: -0.0000
# Episode: 413, Total Reward: -811.9794347925954, Value Loss: 681.3899, Policy Loss: -0.0000
# Episode: 414, Total Reward: -848.4462621721644, Value Loss: 699.6915, Policy Loss: -0.0000
# Episode: 415, Total Reward: -746.9072572666172, Value Loss: 858.8449, Policy Loss: 0.0000
# Episode: 416, Total Reward: -803.7151928094582, Value Loss: 819.0239, Policy Loss: -0.0000
# Episode: 417, Total Reward: -657.6559923323055, Value Loss: 917.8961, Policy Loss: 0.0000
# Episode: 418, Total Reward: -904.3085546950585, Value Loss: 751.0680, Policy Loss: -0.0000
# Episode: 419, Total Reward: -951.9191329878532, Value Loss: 1208.7771, Policy Loss: -0.0000
# Episode: 420, Total Reward: -844.4202987608172, Value Loss: 716.1023, Policy Loss: 0.0000
# Episode: 421, Total Reward: -899.4520904025416, Value Loss: 795.0887, Policy Loss: 0.0000
# Episode: 422, Total Reward: -862.7228052216894, Value Loss: 826.5969, Policy Loss: 0.0000
# Episode: 423, Total Reward: -917.5835532058652, Value Loss: 827.7367, Policy Loss: 0.0000
# Episode: 424, Total Reward: -908.7791118461616, Value Loss: 843.1760, Policy Loss: 0.0000
# Episode: 425, Total Reward: -987.3986872647531, Value Loss: 1265.8324, Policy Loss: -0.0000
# Episode: 426, Total Reward: -882.2406161233648, Value Loss: 837.7338, Policy Loss: 0.0000
# Episode: 427, Total Reward: -839.1811580303157, Value Loss: 645.9219, Policy Loss: -0.0000
# Episode: 428, Total Reward: -760.9828165838966, Value Loss: 798.1379, Policy Loss: -0.0000
# Episode: 429, Total Reward: -852.0426099549603, Value Loss: 771.7484, Policy Loss: 0.0000
# Episode: 430, Total Reward: -774.8469339070433, Value Loss: 743.1602, Policy Loss: 0.0000
# Episode: 431, Total Reward: -747.7861973267901, Value Loss: 974.1167, Policy Loss: -0.0000
# Episode: 432, Total Reward: -675.771312782575, Value Loss: 812.1746, Policy Loss: -0.0000
# Episode: 433, Total Reward: -701.7508322121458, Value Loss: 638.6287, Policy Loss: 0.0000
# Episode: 434, Total Reward: -727.2793690074128, Value Loss: 767.5947, Policy Loss: -0.0000
# Episode: 435, Total Reward: -785.7035313343671, Value Loss: 532.1494, Policy Loss: 0.0000
# Episode: 436, Total Reward: -739.1271937215984, Value Loss: 678.6077, Policy Loss: -0.0000
# Episode: 437, Total Reward: -802.0324701659753, Value Loss: 616.4255, Policy Loss: 0.0000
# Episode: 438, Total Reward: -785.3223406162966, Value Loss: 708.1964, Policy Loss: 0.0000
# Episode: 439, Total Reward: -864.1944806362673, Value Loss: 571.2964, Policy Loss: 0.0000
# Episode: 440, Total Reward: -694.6925318383886, Value Loss: 569.5933, Policy Loss: 0.0000
# Episode: 441, Total Reward: -850.4448538596055, Value Loss: 595.0174, Policy Loss: -0.0000
# Episode: 442, Total Reward: -812.6595290189941, Value Loss: 760.4665, Policy Loss: -0.0000
# Episode: 443, Total Reward: -888.4258832889767, Value Loss: 620.1600, Policy Loss: -0.0000
# Episode: 444, Total Reward: -862.2029287712774, Value Loss: 907.8423, Policy Loss: 0.0000
# Episode: 445, Total Reward: -908.8492273892267, Value Loss: 748.5397, Policy Loss: -0.0000
# Episode: 446, Total Reward: -961.6286993242351, Value Loss: 1114.1907, Policy Loss: 0.0000
# Episode: 447, Total Reward: -940.078344958449, Value Loss: 800.9391, Policy Loss: 0.0000
# Episode: 448, Total Reward: -937.7575428267421, Value Loss: 967.1910, Policy Loss: 0.0000
# Episode: 449, Total Reward: -853.6961655333317, Value Loss: 776.9419, Policy Loss: -0.0000
# Episode: 450, Total Reward: -926.088877473353, Value Loss: 759.5145, Policy Loss: 0.0000
# Episode: 451, Total Reward: -865.5998470480374, Value Loss: 921.6235, Policy Loss: -0.0000
# Episode: 452, Total Reward: -879.7163071285552, Value Loss: 727.5573, Policy Loss: -0.0000
# Episode: 453, Total Reward: -883.5617971074571, Value Loss: 809.4089, Policy Loss: -0.0000
# Episode: 454, Total Reward: -873.384568223185, Value Loss: 755.6879, Policy Loss: 0.0000
# Episode: 455, Total Reward: -672.233852956373, Value Loss: 733.6349, Policy Loss: -0.0000
# Episode: 456, Total Reward: -786.0210502839311, Value Loss: 730.5580, Policy Loss: 0.0000
# Episode: 457, Total Reward: -975.4765187672863, Value Loss: 1117.2493, Policy Loss: 0.0000
# Episode: 458, Total Reward: -933.3841981957337, Value Loss: 1206.1344, Policy Loss: -0.0000
# Episode: 459, Total Reward: -980.3440796461424, Value Loss: 818.1978, Policy Loss: 0.0000
# Episode: 460, Total Reward: -828.9675396475672, Value Loss: 731.5125, Policy Loss: -0.0000
# Episode: 461, Total Reward: -872.072120475279, Value Loss: 899.8906, Policy Loss: -0.0000
# Episode: 462, Total Reward: -1045.157939433627, Value Loss: 1229.0615, Policy Loss: -0.0000
# Episode: 463, Total Reward: -852.9896614539283, Value Loss: 730.1065, Policy Loss: -0.0000
# Episode: 464, Total Reward: -857.8971550268535, Value Loss: 1185.4158, Policy Loss: 0.0000
# Episode: 465, Total Reward: -755.7770933692227, Value Loss: 889.0432, Policy Loss: -0.0000
# Episode: 466, Total Reward: -894.5466759371536, Value Loss: 1081.5543, Policy Loss: -0.0000
# Episode: 467, Total Reward: -760.3975833879408, Value Loss: 824.9585, Policy Loss: -0.0000
# Episode: 468, Total Reward: -920.7901125124307, Value Loss: 862.9067, Policy Loss: 0.0000
# Episode: 469, Total Reward: -759.3401183401093, Value Loss: 827.5836, Policy Loss: 0.0000
# Episode: 470, Total Reward: -882.2945049120032, Value Loss: 757.4731, Policy Loss: 0.0000
# Episode: 471, Total Reward: -821.5738628931784, Value Loss: 964.2766, Policy Loss: -0.0000
# Episode: 472, Total Reward: -953.7797506341166, Value Loss: 1216.6753, Policy Loss: 0.0000
# Episode: 473, Total Reward: -818.0317109703408, Value Loss: 641.4962, Policy Loss: -0.0000
# Episode: 474, Total Reward: -677.2443244355908, Value Loss: 800.1112, Policy Loss: 0.0000
# Episode: 475, Total Reward: -713.4500168255454, Value Loss: 709.7499, Policy Loss: 0.0000
# Episode: 476, Total Reward: -850.4452929295421, Value Loss: 624.7902, Policy Loss: 0.0000
# Episode: 477, Total Reward: -699.6250763226158, Value Loss: 504.0160, Policy Loss: 0.0000
# Episode: 478, Total Reward: -858.1088956527639, Value Loss: 579.7272, Policy Loss: -0.0000
# Episode: 479, Total Reward: -908.0499475037226, Value Loss: 829.9671, Policy Loss: 0.0000
# Episode: 480, Total Reward: -865.3801672870201, Value Loss: 1009.5886, Policy Loss: 0.0000
# Episode: 481, Total Reward: -872.1281139158243, Value Loss: 636.6479, Policy Loss: 0.0000
# Episode: 482, Total Reward: -905.2256935394923, Value Loss: 985.8165, Policy Loss: -0.0000
# Episode: 483, Total Reward: -829.1827546283167, Value Loss: 544.5519, Policy Loss: -0.0000
# Episode: 484, Total Reward: -960.5885483724602, Value Loss: 1294.2633, Policy Loss: 0.0000
# Episode: 485, Total Reward: -971.1904624573596, Value Loss: 926.6710, Policy Loss: -0.0000
# Episode: 486, Total Reward: -1008.5994382180457, Value Loss: 1998.5498, Policy Loss: -0.0000
# Episode: 487, Total Reward: -987.8207169407145, Value Loss: 1176.0526, Policy Loss: -0.0000
# Episode: 488, Total Reward: -1115.5565818428627, Value Loss: 1448.0264, Policy Loss: 0.0000
# Episode: 489, Total Reward: -908.3270040198123, Value Loss: 818.5799, Policy Loss: -0.0000
# Episode: 490, Total Reward: -1119.4661753115333, Value Loss: 2025.8403, Policy Loss: 0.0000
# Episode: 491, Total Reward: -1079.010742035172, Value Loss: 1929.5920, Policy Loss: -0.0000
# Episode: 492, Total Reward: -1057.7891173855678, Value Loss: 2306.2710, Policy Loss: 0.0000
# Episode: 493, Total Reward: -948.2417548854437, Value Loss: 949.6147, Policy Loss: 0.0000
# Episode: 494, Total Reward: -990.8403467395349, Value Loss: 1145.8331, Policy Loss: 0.0000
# Episode: 495, Total Reward: -1004.4466083926059, Value Loss: 1126.1057, Policy Loss: -0.0000
# Episode: 496, Total Reward: -1120.7768529943303, Value Loss: 1454.0979, Policy Loss: -0.0000
# Episode: 497, Total Reward: -1228.9064960949124, Value Loss: 2710.6919, Policy Loss: 0.0000
# Episode: 498, Total Reward: -975.6455328735412, Value Loss: 1072.1028, Policy Loss: 0.0000
# Episode: 499, Total Reward: -961.3342881318968, Value Loss: 1402.5861, Policy Loss: -0.0000
# Episode: 500, Total Reward: -887.2288016580078, Value Loss: 1221.7688, Policy Loss: -0.0000
# Episode: 501, Total Reward: -1169.3534669253752, Value Loss: 1835.2002, Policy Loss: 0.0000
# Episode: 502, Total Reward: -1045.4503103390086, Value Loss: 1087.1779, Policy Loss: 0.0000
# Episode: 503, Total Reward: -993.7643774227652, Value Loss: 782.7460, Policy Loss: 0.0000
# Episode: 504, Total Reward: -764.8684260154657, Value Loss: 720.1262, Policy Loss: -0.0000
# Episode: 505, Total Reward: -928.0782384773947, Value Loss: 987.5477, Policy Loss: -0.0000
# Episode: 506, Total Reward: -1160.0498806249755, Value Loss: 2119.5391, Policy Loss: 0.0000
# Episode: 507, Total Reward: -920.127706410415, Value Loss: 876.0186, Policy Loss: -0.0000
# Episode: 508, Total Reward: -868.736447893279, Value Loss: 827.3452, Policy Loss: -0.0000
# Episode: 509, Total Reward: -1028.7063629514612, Value Loss: 1714.8408, Policy Loss: -0.0000
# Episode: 510, Total Reward: -930.5814085445628, Value Loss: 929.4561, Policy Loss: -0.0000
# Episode: 511, Total Reward: -867.716427119396, Value Loss: 858.9175, Policy Loss: -0.0000
# Episode: 512, Total Reward: -932.9935588660762, Value Loss: 926.3497, Policy Loss: 0.0000
# Episode: 513, Total Reward: -1032.0034119412812, Value Loss: 970.7430, Policy Loss: 0.0000
# Episode: 514, Total Reward: -958.5744814713787, Value Loss: 696.8394, Policy Loss: -0.0000
# Episode: 515, Total Reward: -931.5115444671255, Value Loss: 816.2441, Policy Loss: 0.0000
# ...
# Episode: 7328, Total Reward: 1909.8136609692638, Value Loss: 4659.6392, Policy Loss: -0.0000
# Episode: 7329, Total Reward: 2066.6040687284185, Value Loss: 5412.0752, Policy Loss: -0.0000
# Episode: 7330, Total Reward: 2175.8623331410686, Value Loss: 4486.9697, Policy Loss: -0.0000
# Episode: 7331, Total Reward: 1855.344078534887, Value Loss: 3200.4646, Policy Loss: -0.0000
# Episode: 7332, Total Reward: 2065.525504424747, Value Loss: 3849.6853, Policy Loss: -0.0000
# Episode: 7333, Total Reward: 2026.5614045556688, Value Loss: 2461.0430, Policy Loss: -0.0000
# Episode: 7334, Total Reward: 2351.2785878602704, Value Loss: 3140.9158, Policy Loss: 0.0000
# Episode: 7335, Total Reward: 1829.9000611740028, Value Loss: 3532.2024, Policy Loss: 0.0000
# Episode: 7336, Total Reward: 2089.3519611125885, Value Loss: 2701.6667, Policy Loss: 0.0000
# Episode: 7337, Total Reward: 2104.0692852084144, Value Loss: 4111.6025, Policy Loss: 0.0000
# Episode: 7338, Total Reward: 1811.0890796521833, Value Loss: 3512.5732, Policy Loss: -0.0000
# Episode: 7339, Total Reward: 1976.9657142437381, Value Loss: 3078.4241, Policy Loss: -0.0000
# Episode: 7340, Total Reward: 2166.8805806532528, Value Loss: 3009.5425, Policy Loss: -0.0000
# Episode: 7341, Total Reward: 1857.336170730459, Value Loss: 3081.9185, Policy Loss: -0.0000
# Episode: 7342, Total Reward: 1716.4889447990531, Value Loss: 3559.2051, Policy Loss: -0.0000
# Episode: 7343, Total Reward: 1531.1789892082725, Value Loss: 4192.7637, Policy Loss: 0.0000
# Episode: 7344, Total Reward: 1356.4523819082303, Value Loss: 5407.2612, Policy Loss: -0.0000
# Episode: 7345, Total Reward: 1716.2775964450652, Value Loss: 2999.6641, Policy Loss: 0.0000
# Episode: 7346, Total Reward: 1812.4134988421351, Value Loss: 3272.1021, Policy Loss: 0.0000
# Episode: 7347, Total Reward: 1651.5861672840056, Value Loss: 3788.4312, Policy Loss: 0.0000
# Episode: 7348, Total Reward: 1614.0665062506623, Value Loss: 2950.5425, Policy Loss: -0.0000
# Episode: 7349, Total Reward: 2064.462717995418, Value Loss: 3568.2759, Policy Loss: -0.0000
# Episode: 7350, Total Reward: 1354.392503710096, Value Loss: 3915.7910, Policy Loss: -0.0000
# Episode: 7351, Total Reward: 1727.698213742371, Value Loss: 3345.9053, Policy Loss: 0.0000
# Episode: 7352, Total Reward: 929.2616282239585, Value Loss: 5824.8828, Policy Loss: 0.0000
# Episode: 7353, Total Reward: 1053.650223139004, Value Loss: 4905.8433, Policy Loss: -0.0000
# Episode: 7354, Total Reward: 850.3892428922666, Value Loss: 6382.5171, Policy Loss: 0.0000
# Episode: 7355, Total Reward: 1149.18498267423, Value Loss: 3739.4446, Policy Loss: -0.0000
# Episode: 7356, Total Reward: 1040.9743931874984, Value Loss: 4021.0415, Policy Loss: -0.0000
# Episode: 7357, Total Reward: 1290.0172503536178, Value Loss: 3841.7976, Policy Loss: 0.0000
# Episode: 7358, Total Reward: 1745.2753572637112, Value Loss: 3556.6479, Policy Loss: -0.0000
# Episode: 7359, Total Reward: 1664.2866469092503, Value Loss: 2830.2676, Policy Loss: 0.0000
# Episode: 7360, Total Reward: 1955.0490975193197, Value Loss: 3216.8264, Policy Loss: -0.0000
# Episode: 7361, Total Reward: 1972.3468154179302, Value Loss: 3148.5691, Policy Loss: 0.0000
# Episode: 7362, Total Reward: 2117.9856260354504, Value Loss: 3156.4309, Policy Loss: -0.0000
# Episode: 7363, Total Reward: 1909.1438097788257, Value Loss: 2564.2026, Policy Loss: 0.0000
# Episode: 7364, Total Reward: 1998.473502989571, Value Loss: 2773.1194, Policy Loss: 0.0000
# Episode: 7365, Total Reward: 2169.5103601921946, Value Loss: 4449.1997, Policy Loss: 0.0000
# Episode: 7366, Total Reward: 2307.6784268333654, Value Loss: 4928.5571, Policy Loss: 0.0000
# Episode: 7367, Total Reward: 2206.6318872944335, Value Loss: 5170.4976, Policy Loss: -0.0000
# Episode: 7368, Total Reward: 1692.375614125996, Value Loss: 2283.1099, Policy Loss: 0.0000
# Episode: 7369, Total Reward: 2150.917863052416, Value Loss: 4226.1406, Policy Loss: -0.0000
# Episode: 7370, Total Reward: 2138.7695043355448, Value Loss: 4793.9492, Policy Loss: 0.0000
# Episode: 7371, Total Reward: 2100.3005616369837, Value Loss: 3639.4058, Policy Loss: 0.0000
# Episode: 7372, Total Reward: 2349.212236320349, Value Loss: 5591.0410, Policy Loss: -0.0000
# Episode: 7373, Total Reward: 2404.124664459765, Value Loss: 5936.2334, Policy Loss: -0.0000
# Episode: 7374, Total Reward: 2294.679094028838, Value Loss: 5002.9092, Policy Loss: 0.0000
# Episode: 7375, Total Reward: 2603.4341223546908, Value Loss: 8408.4160, Policy Loss: 0.0000
# Episode: 7376, Total Reward: 2205.8952584154486, Value Loss: 4457.3696, Policy Loss: -0.0000
# Episode: 7377, Total Reward: 2043.171480056666, Value Loss: 4571.7217, Policy Loss: -0.0000
# Episode: 7378, Total Reward: 2345.6874117546, Value Loss: 4670.9219, Policy Loss: -0.0000
# Episode: 7379, Total Reward: 2358.281334021474, Value Loss: 4904.7339, Policy Loss: 0.0000
# Episode: 7380, Total Reward: 2453.7550016263936, Value Loss: 6151.5420, Policy Loss: 0.0000
# Episode: 7381, Total Reward: 2105.1213229288455, Value Loss: 3709.8931, Policy Loss: -0.0000
# Episode: 7382, Total Reward: 2044.7307403185534, Value Loss: 3079.3984, Policy Loss: 0.0000
# Episode: 7383, Total Reward: 2270.995360718361, Value Loss: 3854.4810, Policy Loss: -0.0000
# Episode: 7384, Total Reward: 2006.269246982838, Value Loss: 3500.6909, Policy Loss: -0.0000
# Episode: 7385, Total Reward: 2408.879743718622, Value Loss: 4055.9478, Policy Loss: 0.0000
# Episode: 7386, Total Reward: 2255.8454607611175, Value Loss: 3768.5127, Policy Loss: -0.0000
# Episode: 7387, Total Reward: 2238.848857925397, Value Loss: 3182.7100, Policy Loss: -0.0000
# Episode: 7388, Total Reward: 2273.0522039596954, Value Loss: 3721.0867, Policy Loss: 0.0000
# Episode: 7389, Total Reward: 2482.857673986172, Value Loss: 3701.2771, Policy Loss: 0.0000
# Episode: 7390, Total Reward: 2012.6340671142812, Value Loss: 3286.0134, Policy Loss: -0.0000
# Episode: 7391, Total Reward: 2303.3245578152323, Value Loss: 3884.8655, Policy Loss: 0.0000
# Episode: 7392, Total Reward: 2522.3076493955814, Value Loss: 4647.6509, Policy Loss: 0.0000
# Episode: 7393, Total Reward: 2172.9875293916325, Value Loss: 2955.9587, Policy Loss: 0.0000
# Episode: 7394, Total Reward: 2480.079892230542, Value Loss: 3998.4226, Policy Loss: -0.0000
# Episode: 7395, Total Reward: 2400.959007091369, Value Loss: 3240.3025, Policy Loss: -0.0000
# Episode: 7396, Total Reward: 2313.887893930197, Value Loss: 3413.1030, Policy Loss: 0.0000
# Episode: 7397, Total Reward: 2249.7964440193928, Value Loss: 5591.1226, Policy Loss: 0.0000
# Episode: 7398, Total Reward: 2132.5191394791996, Value Loss: 3152.1130, Policy Loss: 0.0000
# Episode: 7399, Total Reward: 2242.458725101803, Value Loss: 5190.1436, Policy Loss: -0.0000
# Episode: 7400, Total Reward: 2211.498902416894, Value Loss: 4041.6248, Policy Loss: 0.0000
# Episode: 7401, Total Reward: 2653.3586673037016, Value Loss: 4197.4722, Policy Loss: 0.0000
# Episode: 7402, Total Reward: 2078.1713913930857, Value Loss: 3177.6807, Policy Loss: 0.0000
# Episode: 7403, Total Reward: 2454.2503554913997, Value Loss: 4522.3784, Policy Loss: 0.0000
# Episode: 7404, Total Reward: 2216.389742588641, Value Loss: 3554.0706, Policy Loss: 0.0000
# Episode: 7405, Total Reward: 2485.557529993285, Value Loss: 4444.9790, Policy Loss: 0.0000
# Episode: 7406, Total Reward: 2538.3742070379767, Value Loss: 4200.0542, Policy Loss: -0.0000
# Episode: 7407, Total Reward: 2404.7891099074177, Value Loss: 2812.4504, Policy Loss: 0.0000
# Episode: 7408, Total Reward: 2305.155272563572, Value Loss: 2906.9885, Policy Loss: 0.0000
# Episode: 7409, Total Reward: 2376.241213038916, Value Loss: 2850.7202, Policy Loss: 0.0000
# Episode: 7410, Total Reward: 2213.371467872757, Value Loss: 3449.6318, Policy Loss: -0.0000
# Episode: 7411, Total Reward: 2340.6221649057134, Value Loss: 3644.5791, Policy Loss: 0.0000
# Episode: 7412, Total Reward: 2019.3565907831562, Value Loss: 3938.5610, Policy Loss: -0.0000
# Episode: 7413, Total Reward: 1655.7001528485405, Value Loss: 4407.5200, Policy Loss: 0.0000
# Episode: 7414, Total Reward: 2477.5338672641074, Value Loss: 3742.2021, Policy Loss: 0.0000
# Episode: 7415, Total Reward: 2191.8332964654187, Value Loss: 3121.3684, Policy Loss: 0.0000
# Episode: 7416, Total Reward: 2121.705597838289, Value Loss: 2787.1943, Policy Loss: 0.0000
# Episode: 7417, Total Reward: 2474.5183827843252, Value Loss: 3414.5024, Policy Loss: 0.0000
# Episode: 7418, Total Reward: 2282.2102419371904, Value Loss: 2927.7122, Policy Loss: 0.0000
# Episode: 7419, Total Reward: 2137.291534965828, Value Loss: 3239.5471, Policy Loss: -0.0000
# Episode: 7420, Total Reward: 1988.753214303141, Value Loss: 2185.7595, Policy Loss: 0.0000
# Episode: 7421, Total Reward: 2509.636138392633, Value Loss: 3779.6274, Policy Loss: -0.0000
# Episode: 7422, Total Reward: 1989.0353473272748, Value Loss: 2392.6121, Policy Loss: 0.0000
# Episode: 7423, Total Reward: 2017.5524051123207, Value Loss: 2767.6594, Policy Loss: 0.0000
# Episode: 7424, Total Reward: 2142.3790344096747, Value Loss: 2235.9929, Policy Loss: 0.0000
# Episode: 7425, Total Reward: 1965.479715006512, Value Loss: 2428.4771, Policy Loss: -0.0000
# Episode: 7426, Total Reward: 2248.0853681965727, Value Loss: 3774.2314, Policy Loss: -0.0000
# Episode: 7427, Total Reward: 2149.5001981762725, Value Loss: 2176.2444, Policy Loss: 0.0000
# Episode: 7428, Total Reward: 2155.964237744203, Value Loss: 2395.8145, Policy Loss: 0.0000
# Episode: 7429, Total Reward: 1726.144765324005, Value Loss: 2851.5093, Policy Loss: -0.0000
# Episode: 7430, Total Reward: 1958.1474625546123, Value Loss: 2924.2839, Policy Loss: -0.0000
# Episode: 7431, Total Reward: 2062.561464575073, Value Loss: 3044.8630, Policy Loss: -0.0000
# Episode: 7432, Total Reward: 2024.6100398516442, Value Loss: 2824.5273, Policy Loss: -0.0000
# Episode: 7433, Total Reward: 1927.3171494897952, Value Loss: 2727.3237, Policy Loss: 0.0000
# Episode: 7434, Total Reward: 1879.7963255054262, Value Loss: 3098.3469, Policy Loss: 0.0000
# Episode: 7435, Total Reward: 1982.0692789427333, Value Loss: 2774.5981, Policy Loss: -0.0000
# Episode: 7436, Total Reward: 2000.158972981481, Value Loss: 2575.0354, Policy Loss: -0.0000
# Episode: 7437, Total Reward: 1946.9385134697677, Value Loss: 3802.2305, Policy Loss: 0.0000
# Episode: 7438, Total Reward: 1778.2427548525268, Value Loss: 3132.1050, Policy Loss: -0.0000
# Episode: 7439, Total Reward: 2215.977157238393, Value Loss: 2816.5896, Policy Loss: 0.0000
# Episode: 7440, Total Reward: 2199.7930364915746, Value Loss: 2775.4724, Policy Loss: 0.0000
# Episode: 7441, Total Reward: 2233.8696020982325, Value Loss: 3308.4185, Policy Loss: -0.0000
# Episode: 7442, Total Reward: 2220.1559789712655, Value Loss: 3493.2275, Policy Loss: -0.0000
# Episode: 7443, Total Reward: 1756.463322145503, Value Loss: 3563.9805, Policy Loss: -0.0000
# Episode: 7444, Total Reward: 2088.093834715505, Value Loss: 2755.8970, Policy Loss: -0.0000
# Episode: 7445, Total Reward: 1748.4305155422396, Value Loss: 3705.9146, Policy Loss: 0.0000
# Episode: 7446, Total Reward: 2012.7337875830772, Value Loss: 2737.9834, Policy Loss: -0.0000
# Episode: 7447, Total Reward: 1394.0482721003855, Value Loss: 5517.6089, Policy Loss: -0.0000
# Episode: 7448, Total Reward: 1957.9530839527454, Value Loss: 2359.4890, Policy Loss: -0.0000
# Episode: 7449, Total Reward: 1451.5201156077937, Value Loss: 4818.2612, Policy Loss: 0.0000
# Episode: 7450, Total Reward: 1620.6584763487751, Value Loss: 4359.1099, Policy Loss: -0.0000
# Episode: 7451, Total Reward: 1648.5283195227528, Value Loss: 3731.9175, Policy Loss: -0.0000
# Episode: 7452, Total Reward: 116.91656921858868, Value Loss: 8523.4736, Policy Loss: -0.0000
# Episode: 7453, Total Reward: 1556.8149908139098, Value Loss: 3806.5806, Policy Loss: 0.0000
# Episode: 7454, Total Reward: 2050.7244240893374, Value Loss: 2801.8889, Policy Loss: -0.0000
# Episode: 7455, Total Reward: 1891.5605297290276, Value Loss: 2209.4167, Policy Loss: 0.0000
# Episode: 7456, Total Reward: 1264.037225004213, Value Loss: 6755.4692, Policy Loss: -0.0000
# Episode: 7457, Total Reward: 1545.2346499912119, Value Loss: 2722.5623, Policy Loss: -0.0000
# Episode: 7458, Total Reward: 1436.4250663875237, Value Loss: 3780.2739, Policy Loss: -0.0000
# Episode: 7459, Total Reward: 1570.1098389756194, Value Loss: 2492.9790, Policy Loss: 0.0000
# Episode: 7460, Total Reward: 1452.058523675249, Value Loss: 2821.0317, Policy Loss: 0.0000
# Episode: 7461, Total Reward: 1367.8985983591822, Value Loss: 2446.7109, Policy Loss: -0.0000
# Episode: 7462, Total Reward: 1317.7859365822612, Value Loss: 3017.3855, Policy Loss: 0.0000
# Episode: 7463, Total Reward: 1535.544747985805, Value Loss: 2787.0396, Policy Loss: -0.0000
# Episode: 7464, Total Reward: 1619.1942759162198, Value Loss: 2426.3079, Policy Loss: 0.0000
# Episode: 7465, Total Reward: 1583.9321994420482, Value Loss: 2259.1553, Policy Loss: 0.0000
# Episode: 7466, Total Reward: 1673.1838099104975, Value Loss: 2035.0067, Policy Loss: 0.0000
# Episode: 7467, Total Reward: 1936.4695536498673, Value Loss: 2771.3721, Policy Loss: -0.0000
# Episode: 7468, Total Reward: 1782.4204435468025, Value Loss: 2819.8184, Policy Loss: 0.0000
# Episode: 7469, Total Reward: 2040.494033193046, Value Loss: 2581.3735, Policy Loss: -0.0000
# Episode: 7470, Total Reward: 1996.928842027816, Value Loss: 2664.7717, Policy Loss: -0.0000
# Episode: 7471, Total Reward: 2202.0229819717024, Value Loss: 4047.0063, Policy Loss: 0.0000
# Episode: 7472, Total Reward: 2456.9722570143826, Value Loss: 6315.9771, Policy Loss: 0.0000
# Episode: 7473, Total Reward: 2416.1591731015146, Value Loss: 4794.0566, Policy Loss: 0.0000
# Episode: 7474, Total Reward: 2490.189242503005, Value Loss: 6174.9810, Policy Loss: -0.0000
# Episode: 7475, Total Reward: 2039.549593371269, Value Loss: 3526.5049, Policy Loss: -0.0000
# Episode: 7476, Total Reward: 2239.3818850616026, Value Loss: 3798.4919, Policy Loss: 0.0000
# Episode: 7477, Total Reward: 1956.191636247474, Value Loss: 2685.3438, Policy Loss: -0.0000
# Episode: 7478, Total Reward: 1886.6365568126416, Value Loss: 3648.5859, Policy Loss: -0.0000
# Episode: 7479, Total Reward: 2284.6456727576588, Value Loss: 4922.9839, Policy Loss: -0.0000
# Episode: 7480, Total Reward: 2763.585888762297, Value Loss: 8524.7793, Policy Loss: -0.0000
# Episode: 7481, Total Reward: 2012.4970356641486, Value Loss: 2667.8684, Policy Loss: -0.0000
# Episode: 7482, Total Reward: 1733.6244921724374, Value Loss: 3805.5154, Policy Loss: -0.0000
# Episode: 7483, Total Reward: 2061.562734138605, Value Loss: 3083.5149, Policy Loss: 0.0000
# Episode: 7484, Total Reward: 2099.312796047027, Value Loss: 3250.7559, Policy Loss: 0.0000
# Episode: 7485, Total Reward: 2238.1818973473783, Value Loss: 5529.3428, Policy Loss: 0.0000
# Episode: 7486, Total Reward: 2166.202648396604, Value Loss: 3666.9290, Policy Loss: -0.0000
# Episode: 7487, Total Reward: 2291.427933645999, Value Loss: 4085.8875, Policy Loss: -0.0000
# Episode: 7488, Total Reward: 2102.6768433103666, Value Loss: 3273.5659, Policy Loss: -0.0000
# Episode: 7489, Total Reward: 2657.8471200012027, Value Loss: 8171.3682, Policy Loss: -0.0000
# Episode: 7490, Total Reward: 2391.378759410372, Value Loss: 4535.8628, Policy Loss: -0.0000
# Episode: 7491, Total Reward: 2352.841684588229, Value Loss: 4782.2261, Policy Loss: 0.0000
# Episode: 7492, Total Reward: 1913.3751980580714, Value Loss: 3411.6545, Policy Loss: 0.0000
# Episode: 7493, Total Reward: 2570.3083853394633, Value Loss: 5337.5640, Policy Loss: 0.0000
# Episode: 7494, Total Reward: 2397.9239870768442, Value Loss: 4715.0747, Policy Loss: 0.0000
# Episode: 7495, Total Reward: 2728.8536754338998, Value Loss: 6635.6499, Policy Loss: -0.0000
# Episode: 7496, Total Reward: 2556.047364365607, Value Loss: 6490.1851, Policy Loss: 0.0000
# Episode: 7497, Total Reward: 2459.8395109374837, Value Loss: 4054.7485, Policy Loss: 0.0000
# Episode: 7498, Total Reward: 2506.8542648056055, Value Loss: 5173.7324, Policy Loss: 0.0000
# Episode: 7499, Total Reward: 2126.5524550209266, Value Loss: 3271.3245, Policy Loss: 0.0000
# Episode: 7500, Total Reward: 2688.453537488208, Value Loss: 5164.8672, Policy Loss: -0.0000

# %%
import os
import gymnasium as gym
import imageio
import numpy as np

def create_video_manual(agent, env_id, filename, video_length, fps):
    """
    Create a video by manually capturing frames from the environment and
    saving them as a video file.
    
    Args:
        agent: The trained agent (with a policy network).
        env_id (str): Environment ID (e.g., "HalfCheetah-v5").
        filename (str): Output filename for the video (including path).
        video_length (int): Total number of steps to record.
        fps (int): Frames per second for the output video.
    """
    video_dir = './vid'
    if not os.path.exists(video_dir):
        os.makedirs(video_dir)
    
    # Create the environment with render_mode set to 'rgb_array'
    env = gym.make(env_id, render_mode='rgb_array')
    # Optionally, force the metadata to use your desired FPS:
    env.metadata['video.frames_per_second'] = fps

    frames = []
    state, _ = env.reset()

    for _ in range(video_length):
        # Capture the frame
        frame = env.render()  # This returns an RGB image
        frames.append(frame)
        
        # Get action from your agent's policy network.
        # (Make sure your agent is built with the correct observation/action sizes for HalfCheetah)
        action, _ = agent.policy_net.get_action(state)
        state, reward, done, truncated, _ = env.step(action)
        
        # If the episode terminates early, reset the environment
        if done or truncated:
            state, _ = env.reset()

    env.close()
    
    # Save the frames to a video file using imageio
    video_path = os.path.join(video_dir, filename)
    imageio.mimsave(video_path, frames, fps=fps)
    print("Video saved as:", video_path)

# Example usage:
# (Make sure your agent was created using the appropriate observation and action dimensions for HalfCheetah-v5.)
create_video_manual(agent, env_id="HalfCheetah-v5", filename="half_cheetah_agent.mp4", video_length=500, fps=30)
# Out:
# Video saved as: ./vid/half_cheetah_agent.mp4

# %%
import imageio_ffmpeg
print(imageio_ffmpeg.get_ffmpeg_version())
# Out:
# 7.1
